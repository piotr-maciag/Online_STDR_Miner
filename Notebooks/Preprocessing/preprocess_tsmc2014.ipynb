# %% [markdown]
# # Preprocess TSMC2014 datasets
#
# This notebook converts the raw TSMC2014 New York and Tokyo check-in files into CSV event datasets with artificial event IDs, coordinates, minutes since the first event, absolute occurrence time from the raw UTC timestamp, and event type.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "Notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT / "Source"))

from preprocess_tsmc2014 import preprocess_all

# %%
raw_dir = PROJECT_ROOT / "Data" / "Raw"
output_dir = PROJECT_ROOT / "Data" / "Preprocessed"

output_paths = preprocess_all(raw_dir=raw_dir, output_dir=output_dir)
output_paths
# Out:
# [PosixPath('/Users/piotr/Praca/Nauka/publikacje/SNNs_ST_Patterns/Experiments_software/Data/Preprocessed/dataset_TSMC2014_NYC_preprocessed.csv'),
#  PosixPath('/Users/piotr/Praca/Nauka/publikacje/SNNs_ST_Patterns/Experiments_software/Data/Preprocessed/dataset_TSMC2014_TKY_preprocessed.csv')]

# %%
import pandas as pd

for path in output_paths:
    data = pd.read_csv(path)
    print(path.name)
    display(data.head())
    print(data.shape)
    print()
# Out:
# dataset_TSMC2014_NYC_preprocessed.csv
#    Event_ID  longitude   latitude  timestamp                 Occurrence_time  \
# 0         1 -74.002581  40.719810   0.000000  Tue Apr 03 18:00:09 +0000 2012
# 1         2 -74.044170  40.606800   0.266667  Tue Apr 03 18:00:25 +0000 2012
# 2         3 -73.883070  40.716162   2.250000  Tue Apr 03 18:02:24 +0000 2012
# 3         4 -73.982519  40.745164   2.533333  Tue Apr 03 18:02:41 +0000 2012
# 4         5 -73.989658  40.740104   2.850000  Tue Apr 03 18:03:00 +0000 2012
#
#             Event_type
# 0  Arts & Crafts Store
# 1               Bridge
# 2       Home (private)
# 3       Medical Center
# 4           Food Truck
# (227428, 6)
#
# dataset_TSMC2014_TKY_preprocessed.csv
#    Event_ID   longitude   latitude  timestamp                 Occurrence_time  \
# 0         1  139.619590  35.705101   0.000000  Tue Apr 03 18:17:18 +0000 2012
# 1         2  139.800317  35.715581   4.766667  Tue Apr 03 18:22:04 +0000 2012
# ...
